# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dfc = pd.read_csv('Output\Mid_Car_Cleaned.csv')
dfb = pd.read_csv('Output\Mid_Bike_Cleaned.csv')

# %%
def print_full(x):
    pd.set_option('display.max_rows', None)
    pd.set_option('display.max_columns', None)
    pd.set_option('display.width', 2000)
    pd.set_option('display.float_format', '{:20,.2f}'.format)
    pd.set_option('display.max_colwidth', None)
    print(x)
    pd.reset_option('display.max_rows')
    pd.reset_option('display.max_columns')
    pd.reset_option('display.width')
    pd.reset_option('display.float_format')
    pd.reset_option('display.max_colwidth')

# %%
dfc
# Out:
#              title      price   brand   type  years         milage  \
# 0     toyota yaris  264000000  toyota  yaris   2021  20.000-25.000
# 1     toyota yaris  264000000  toyota  yaris   2021  20.000-25.000
# 2     toyota yaris  264000000  toyota  yaris   2021  20.000-25.000
# 3     toyota yaris  264000000  toyota  yaris   2021  20.000-25.000
# 4     toyota yaris  264000000  toyota  yaris   2021  20.000-25.000
# ...            ...        ...     ...    ...    ...            ...
# 2853    honda brio  138000000   honda   brio   2016  45.000-50.000
# 2854    honda brio  137000000   honda   brio   2016  45.000-50.000
# 2855    honda brio  137000000   honda   brio   2016  45.000-50.000
# 2856    honda brio  137000000   honda   brio   2016  45.000-50.000
# 2857    honda brio  126000000   honda   brio   2016  45.000-50.000
#
#                                          location vehicle_type  \
# 0               Candi, Sidoarjo  Kab., Jawa Timur          car
# 1           Sambikerep, Surabaya Kota, Jawa Timur          car
# 2               Krian, Sidoarjo  Kab., Jawa Timur          car
# 3              Porong, Sidoarjo  Kab., Jawa Timur          car
# 4               Tarik, Sidoarjo  Kab., Jawa Timur          car
# ...                                           ...          ...
# 2853              Balung, Jember Kab., Jawa Timur          car
# 2854  Magelang Tengah, Magelang Kota, Jawa Tengah          car
# 2855   Kotagede, Yogyakarta Kota, Yogyakarta D.I.          car
# 2856      Prambanan, Sleman Kab., Yogyakarta D.I.          car
# 2857           Rungkut, Surabaya Kota, Jawa Timur          car
#
#                                                     url  milage_class    fuel  \
# 0     https://www.olx.co.id/item/olx-autos-toyota-ya...             5  Bensin
# 1     https://www.olx.co.id/item/olx-autos-toyota-ya...             5  Bensin
# 2     https://www.olx.co.id/item/olx-autos-toyota-ya...             5  Bensin
# 3     https://www.olx.co.id/item/olx-autos-toyota-ya...             5  Bensin
# 4     https://www.olx.co.id/item/olx-autos-toyota-ya...             5  Bensin
# ...                                                 ...           ...     ...
# 2853  https://www.olx.co.id/item/honda-brio-rs-mt-ii...            10  Bensin
# 2854  https://www.olx.co.id/item/dp-21jt-honda-brio-...            10  Bensin
# 2855  https://www.olx.co.id/item/dp-24-jt-honda-brio...            10  Bensin
# 2856  https://www.olx.co.id/item/dp-17juta-brio-rs-a...            10  Bensin
# 2857  https://www.olx.co.id/item/honda-brio-e-satya-...            10  Bensin
#
#      transmission
# 0       Automatic
# 1       Automatic
# 2       Automatic
# 3       Automatic
# 4       Automatic
# ...           ...
# 2853       Manual
# 2854    Automatic
# 2855    Automatic
# 2856    Automatic
# 2857       Manual
#
# [2858 rows x 12 columns]

# %%
dfb
# Out:
#                                                   title     price   brand  \
# 0     KREDIT YAMAHA MIO GEAR 2021 DP 3,000,000 PROSE...  15450000  yamaha
# 1     KREDIT DP 3,000,000 YAMAHA MIO GEAR 2021 ISTIMEWA  15450000  yamaha
# 2        (GRESS UNIT) DP 900 RB YAMAHA MIO GEAR TH 2021  14700000  yamaha
# 3                DP 900K YAMAHA MIO GEAR 125 CC TH 2021  14700000  yamaha
# 4                DP 900K YAMAHA MIO GEAR 125 CC TH 2021  14700000  yamaha
# ...                                                 ...       ...     ...
# 3447  beat esp 2016 bisa cash atau kredit ato tukart...   9000000   honda
# 3448  beat esp fi 2016 merah putih bisa cash atau kr...   9000000   honda
# 3449  beat esp 2016 bisa cash atau kredit ato tukart...   9000000   honda
# 3450  beat esp 2016 hitam bisa cash ato kredit ato t...   8800000   honda
# 3451  beat fi 2014 merah bisa cash ato kredit ato tu...   8300000   honda
#
#       type  years         milage                                    location  \
# 0      mio   2021  10.000-15.000   Pasar Rebo, Jakarta Timur, Jakarta D.K.I.
# 1      mio   2021  10.000-15.000     Cipayung, Jakarta Timur, Jakarta D.K.I.
# 2      mio   2021  10.000-15.000  Jagakarsa, Jakarta Selatan, Jakarta D.K.I.
# 3      mio   2021  10.000-15.000  Duren Sawit, Jakarta Timur, Jakarta D.K.I.
# 4      mio   2021  10.000-15.000           Cimanggis, Depok Kota, Jawa Barat
# ...    ...    ...            ...                                         ...
# 3447  beat   2016        0-5.000       Gamping, Sleman Kab., Yogyakarta D.I.
# 3448  beat   2016        0-5.000       Ngaglik, Sleman Kab., Yogyakarta D.I.
# 3449  beat   2016        0-5.000         Sewon, Bantul Kab., Yogyakarta D.I.
# 3450  beat   2016        0-5.000         Mlati, Sleman Kab., Yogyakarta D.I.
# 3451  beat   2016        0-5.000         Depok, Sleman Kab., Yogyakarta D.I.
#
#      vehicle_type                                                url  \
# 0            bike  https://www.olx.co.id/item/kredit-dp-3000000-y...
# 1            bike  https://www.olx.co.id/item/kredit-yamaha-mio-g...
# 2            bike  https://www.olx.co.id/item/dp-cuma-900-rb-aja-...
# 3            bike  https://www.olx.co.id/item/low-km-dp-900k-yama...
# 4            bike  https://www.olx.co.id/item/dp-cuma-900k-yamaha...
# ...           ...                                                ...
# 3447         bike  https://www.olx.co.id/item/beat-esp-2016-bisa-...
# 3448         bike  https://www.olx.co.id/item/beat-fi-esp-2016-bi...
# 3449         bike  https://www.olx.co.id/item/beat-esp-2016-bisa-...
# 3450         bike  https://www.olx.co.id/item/beat-esp-2016-merah...
# 3451         bike  https://www.olx.co.id/item/beat-fi-2016-bisa-k...
#
#       milage_class
# 0                3
# 1                3
# 2                3
# 3                3
# 4                3
# ...            ...
# 3447             1
# 3448             1
# 3449             1
# 3450             1
# 3451             1
#
# [3452 rows x 10 columns]

# %%
g = sns.FacetGrid(dfb, col='type', margin_titles=True, height=8, aspect= 0.5, sharey=False, sharex=False)
g.map(sns.regplot, "years", "price", color=".3", fit_reg=False, x_jitter=.1)

# %%
g = sns.FacetGrid(dfb, col='type', margin_titles=True, height=24, aspect= 0.5, sharey=True, sharex=False)
g.map(sns.boxplot, 'years', 'price')
# Out:
# c:\Users\Test\miniconda3\envs\min_library\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
sns.relplot(
    data=dfb, x="years", y="price",
    col="type", kind='line', height=10, aspect=0.8, facet_kws={'sharey': True, 'sharex': False}
)

# %%
g = sns.FacetGrid(dfb, col='type', margin_titles=True, height=10, aspect= 0.5, sharey=True, sharex=False)
g.map(sns.regplot, "milage_class", "price", color=".3", fit_reg=False, x_jitter=.1)

# %%
g = sns.FacetGrid(dfc, col='type', margin_titles=True, height=12, aspect= 0.5, sharey=False, sharex=False)
g.map(sns.regplot, "years", "price", color=".3", fit_reg=False, x_jitter=.1)

# %%
g = sns.FacetGrid(dfc, col='type', margin_titles=True, height=24, aspect= 0.5, sharey=False, sharex=False)
g.map(sns.boxplot, 'years', 'price')
# Out:
# c:\Users\Test\miniconda3\envs\min_library\lib\site-packages\seaborn\axisgrid.py:670: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
sns.relplot(
    data=dfc, x="years", y="price",
    col="type", kind='line', height=10, aspect=0.8, facet_kws={'sharey': False, 'sharex': False}
)

# %%
g = sns.FacetGrid(dfc, col='type', margin_titles=True, height=24, aspect= 0.5, sharey=False,sharex=False)
g.map(sns.regplot, "milage_class", "price", color=".3", fit_reg=False, x_jitter=.1)

# %%
mb =dfb.groupby(['type', 'years']).agg({'price': ['median','mean', 'min', 'max']}).sort_values(by=['type','years'], ascending=False)
mb.columns = ['price_median','price_mean', 'price_min', 'price_max']
mb = mb.reset_index()
mb = pd.DataFrame(data=mb)

# %%
print_full(mb)
# Out:
#          type  years         price_median           price_mean  price_min  price_max
# 0   vario-150   2021        22,575,000.00        22,200,411.52   17000000   24300000
# 1   vario-150   2020        20,000,000.00        20,250,264.33    8900000   24500000
# 2   vario-150   2019        19,700,000.00        19,587,955.41   14750000   24500000
# 3   vario-150   2018        18,500,000.00        18,365,690.07   12500000   23999000
# 4   vario-150   2017        16,450,000.00        16,141,633.32   12000000   20000000
# 5   vario-150   2016        15,225,000.00        15,523,195.48   12500000   19200000
# 6   vario-125   2021        20,900,000.00        20,606,493.98   16500000   23800000
# 7   vario-125   2020        19,000,000.00        19,045,653.52   15000000   22800000
# 8   vario-125   2019        17,850,000.00        17,665,330.71   11950000   24300000
# 9   vario-125   2018        16,800,000.00        16,733,625.20    9500000   22300000
# 10  vario-125   2017        14,950,000.00        14,981,019.44   10500000   19800000
# 11  vario-125   2016        13,950,000.00        14,048,137.25   10000000   20555000
# 12     scoopy   2021        20,800,000.00        20,813,494.59    5500000   23500000
# 13     scoopy   2020        20,000,000.00        19,215,769.23    4250000   23200000
# 14     scoopy   2019        18,500,000.00        18,708,899.22   14500000   22700000
# 15     scoopy   2018        17,725,000.00        17,447,291.54   12000000   21500000
# 16     scoopy   2017        15,500,000.00        15,694,211.54   11500000   19800000
# 17     scoopy   2016        13,800,000.00        13,806,012.36    9100000   20000000
# 18        mio   2021        14,700,000.00        14,432,466.02   11300000   16700000
# 19        mio   2020        12,500,000.00        12,969,230.77    8300000   16750000
# 20        mio   2019        11,950,000.00        11,557,142.86    8500000   14950000
# 21        mio   2018        10,300,000.00        10,070,754.72    6500000   13300000
# 22        mio   2017         8,600,000.00         8,618,333.33    5900000   11000000
# 23        mio   2016         7,800,550.00         8,245,642.00    4400000   12800000
# 24       beat   2021        16,900,000.00        16,923,762.41   12000000   20500000
# 25       beat   2020        15,950,000.00        15,862,937.50   12300000   20200000
# 26       beat   2019        14,500,000.00        14,454,098.70    7800000   18750000
# 27       beat   2018        13,900,000.00        13,759,590.74    7500000   18200000
# 28       beat   2017        12,500,000.00        12,376,253.54    5000000   17000000
# 29       beat   2016        11,425,000.00        11,309,713.04    7000000   17000000

# %%
mc =dfc.groupby(['type', 'years']).agg({'price': ['median','mean', 'min', 'max']}).sort_values(by=['type','years'], ascending=False)
mc.columns = ['price_median','price_mean', 'price_min', 'price_max']
mc = mc.reset_index()
mc = pd.DataFrame(data=mc)

# %%
print_full(mc)
# Out:
#        type  years         price_median           price_mean  price_min  price_max
# 0     yaris   2021       264,000,000.00       257,086,956.52  229000000  285000000
# 1     yaris   2020       240,000,000.00       227,161,290.32  123000000  285000000
# 2     yaris   2019       235,000,000.00       235,895,156.55  205000000  265000000
# 3     yaris   2018       229,000,000.00       224,929,166.67  193000000  243000000
# 4     yaris   2017       178,800,000.00       182,323,017.84  141800000  210000000
# 5     yaris   2016       177,500,000.00       171,773,807.14  155000000  189000000
# 6   xpander   2021       273,500,000.00       269,291,304.35  234000000  296000000
# 7   xpander   2020       255,000,000.00       257,199,971.43  212000000  280000000
# 8   xpander   2019       229,000,000.00       227,784,451.01  185000000  266000000
# 9   xpander   2018       218,500,000.00       215,835,971.22  175000000  243000000
# 10  xpander   2017       200,000,000.00       202,412,500.00  182500000  225000000
# 11     rush   2021       255,000,000.00       256,214,228.57  243000000  280000000
# 12     rush   2020       239,300,000.00       240,654,999.97  225000000  269000000
# 13     rush   2019       231,500,000.00       230,489,062.48  207500000  258900000
# 14     rush   2018       222,999,000.00       220,362,159.42  150000000  250000000
# 15     rush   2017       180,000,000.00       178,262,500.00  165000000  198000000
# 16     rush   2016       175,000,000.00       172,700,000.00  152000000  185000000
# 17     jazz   2021       280,000,000.00       281,000,000.00  280000000  285000000
# 18     jazz   2020       272,000,000.00       271,533,266.67  215000000  332000000
# 19     jazz   2019       260,000,000.00       261,825,454.55  247500000  280000000
# 20     jazz   2018       245,000,000.00       241,726,874.99  189000000  285000000
# 21     jazz   2017       229,000,000.00       225,778,313.25  185000000  257000000
# 22     jazz   2016       206,500,000.00       206,796,969.67  179000000  235000000
# 23   innova   2021       385,000,000.00       387,340,425.51  287000000  460000000
# 24   innova   2020       383,000,000.00       367,664,705.88  280000000  463000000
# 25   innova   2019       338,000,000.00       339,851,898.73  245000000  430000000
# 26   innova   2018       316,000,000.00       315,194,444.44  199000000  409000000
# 27   innova   2017       318,250,000.00       312,005,555.56  245000000  395000000
# 28   innova   2016       278,000,000.00       286,738,095.24  242000000  340000000
# 29     hr-v   2021       325,000,000.00       327,611,111.11  295000000  389000000
# 30     hr-v   2020       307,500,000.00       317,641,500.00  279000000  365000000
# 31     hr-v   2019       288,800,000.00       292,165,242.13  250000000  354999999
# 32     hr-v   2018       285,000,000.00       279,846,938.78  214000000  351000000
# 33     hr-v   2017       238,000,000.00       245,456,138.60  199000000  315000000
# 34     hr-v   2016       219,000,000.00       220,428,052.61  177000000  283000000
# 35     cr-v   2021       552,000,000.00       549,000,000.00  515000000  570000000
# 36     cr-v   2020       499,000,000.00       504,800,000.00  489000000  529000000
# 37     cr-v   2019       457,700,000.00       449,007,333.26  399000000  495000000
# 38     cr-v   2018       440,000,000.00       433,633,333.33  340000000  480000000
# 39     cr-v   2017       340,000,000.00       352,025,581.40  275000000  465000000
# 40     cr-v   2016       274,500,000.00       276,349,999.95  225000000  315000000
# 41     brio   2021       176,000,000.00       178,269,354.82  150000000  211000000
# 42     brio   2020       168,500,000.00       170,287,234.04  142000000  200000000
# 43     brio   2019       167,000,000.00       167,381,944.44  138000000  199500000
# 44     brio   2018       140,000,000.00       142,624,691.36  114000000  183000000
# 45     brio   2017       132,250,000.00       132,128,301.89  112000000  152000000
# 46     brio   2016       130,000,000.00       127,779,636.36  105000000  155000000
# 47   avanza   2021       239,750,000.00       252,117,647.06  162000000  315000000
# 48   avanza   2020       196,000,000.00       200,000,000.00  165000000  275000000
# 49   avanza   2019       191,000,000.00       187,859,459.46  155000000  217000000
# 50   avanza   2018       164,000,000.00       161,627,450.98  135000000  191000000
# 51   avanza   2017       150,000,000.00       151,969,135.80  119000000  188000000
# 52   avanza   2016       147,500,000.00       145,806,153.85  120000000  170000000

# %%
mc['index'] = mc.price_median / mc.groupby('type').price_median.transform(np.max)

# %%
print_full(mc)
# Out:
#        type  years         price_median           price_mean  price_min  price_max                index
# 0     yaris   2021       264,000,000.00       257,086,956.52  229000000  285000000                 1.00
# 1     yaris   2020       240,000,000.00       227,161,290.32  123000000  285000000                 0.91
# 2     yaris   2019       235,000,000.00       235,895,156.55  205000000  265000000                 0.89
# 3     yaris   2018       229,000,000.00       224,929,166.67  193000000  243000000                 0.87
# 4     yaris   2017       178,800,000.00       182,323,017.84  141800000  210000000                 0.68
# 5     yaris   2016       177,500,000.00       171,773,807.14  155000000  189000000                 0.67
# 6   xpander   2021       273,500,000.00       269,291,304.35  234000000  296000000                 1.00
# 7   xpander   2020       255,000,000.00       257,199,971.43  212000000  280000000                 0.93
# 8   xpander   2019       229,000,000.00       227,784,451.01  185000000  266000000                 0.84
# 9   xpander   2018       218,500,000.00       215,835,971.22  175000000  243000000                 0.80
# 10  xpander   2017       200,000,000.00       202,412,500.00  182500000  225000000                 0.73
# 11     rush   2021       255,000,000.00       256,214,228.57  243000000  280000000                 1.00
# 12     rush   2020       239,300,000.00       240,654,999.97  225000000  269000000                 0.94
# 13     rush   2019       231,500,000.00       230,489,062.48  207500000  258900000                 0.91
# 14     rush   2018       222,999,000.00       220,362,159.42  150000000  250000000                 0.87
# 15     rush   2017       180,000,000.00       178,262,500.00  165000000  198000000                 0.71
# 16     rush   2016       175,000,000.00       172,700,000.00  152000000  185000000                 0.69
# 17     jazz   2021       280,000,000.00       281,000,000.00  280000000  285000000                 1.00
# 18     jazz   2020       272,000,000.00       271,533,266.67  215000000  332000000                 0.97
# 19     jazz   2019       260,000,000.00       261,825,454.55  247500000  280000000                 0.93
# 20     jazz   2018       245,000,000.00       241,726,874.99  189000000  285000000                 0.88
# 21     jazz   2017       229,000,000.00       225,778,313.25  185000000  257000000                 0.82
# 22     jazz   2016       206,500,000.00       206,796,969.67  179000000  235000000                 0.74
# 23   innova   2021       385,000,000.00       387,340,425.51  287000000  460000000                 1.00
# 24   innova   2020       383,000,000.00       367,664,705.88  280000000  463000000                 0.99
# 25   innova   2019       338,000,000.00       339,851,898.73  245000000  430000000                 0.88
# 26   innova   2018       316,000,000.00       315,194,444.44  199000000  409000000                 0.82
# 27   innova   2017       318,250,000.00       312,005,555.56  245000000  395000000                 0.83
# 28   innova   2016       278,000,000.00       286,738,095.24  242000000  340000000                 0.72
# 29     hr-v   2021       325,000,000.00       327,611,111.11  295000000  389000000                 1.00
# 30     hr-v   2020       307,500,000.00       317,641,500.00  279000000  365000000                 0.95
# 31     hr-v   2019       288,800,000.00       292,165,242.13  250000000  354999999                 0.89
# 32     hr-v   2018       285,000,000.00       279,846,938.78  214000000  351000000                 0.88
# 33     hr-v   2017       238,000,000.00       245,456,138.60  199000000  315000000                 0.73
# 34     hr-v   2016       219,000,000.00       220,428,052.61  177000000  283000000                 0.67
# 35     cr-v   2021       552,000,000.00       549,000,000.00  515000000  570000000                 1.00
# 36     cr-v   2020       499,000,000.00       504,800,000.00  489000000  529000000                 0.90
# 37     cr-v   2019       457,700,000.00       449,007,333.26  399000000  495000000                 0.83
# 38     cr-v   2018       440,000,000.00       433,633,333.33  340000000  480000000                 0.80
# 39     cr-v   2017       340,000,000.00       352,025,581.40  275000000  465000000                 0.62
# 40     cr-v   2016       274,500,000.00       276,349,999.95  225000000  315000000                 0.50
# 41     brio   2021       176,000,000.00       178,269,354.82  150000000  211000000                 1.00
# 42     brio   2020       168,500,000.00       170,287,234.04  142000000  200000000                 0.96
# 43     brio   2019       167,000,000.00       167,381,944.44  138000000  199500000                 0.95
# 44     brio   2018       140,000,000.00       142,624,691.36  114000000  183000000                 0.80
# 45     brio   2017       132,250,000.00       132,128,301.89  112000000  152000000                 0.75
# 46     brio   2016       130,000,000.00       127,779,636.36  105000000  155000000                 0.74
# 47   avanza   2021       239,750,000.00       252,117,647.06  162000000  315000000                 1.00
# 48   avanza   2020       196,000,000.00       200,000,000.00  165000000  275000000                 0.82
# 49   avanza   2019       191,000,000.00       187,859,459.46  155000000  217000000                 0.80
# 50   avanza   2018       164,000,000.00       161,627,450.98  135000000  191000000                 0.68
# 51   avanza   2017       150,000,000.00       151,969,135.80  119000000  188000000                 0.63
# 52   avanza   2016       147,500,000.00       145,806,153.85  120000000  170000000                 0.62

# %%
mb['index'] = mb.price_median / mb.groupby('type').price_median.transform(np.max)

# %%
print_full(mb)
# Out:
#          type  years         price_median           price_mean  price_min  price_max                index
# 0   vario-150   2021        22,575,000.00        22,200,411.52   17000000   24300000                 1.00
# 1   vario-150   2020        20,000,000.00        20,250,264.33    8900000   24500000                 0.89
# 2   vario-150   2019        19,700,000.00        19,587,955.41   14750000   24500000                 0.87
# 3   vario-150   2018        18,500,000.00        18,365,690.07   12500000   23999000                 0.82
# 4   vario-150   2017        16,450,000.00        16,141,633.32   12000000   20000000                 0.73
# 5   vario-150   2016        15,225,000.00        15,523,195.48   12500000   19200000                 0.67
# 6   vario-125   2021        20,900,000.00        20,606,493.98   16500000   23800000                 1.00
# 7   vario-125   2020        19,000,000.00        19,045,653.52   15000000   22800000                 0.91
# 8   vario-125   2019        17,850,000.00        17,665,330.71   11950000   24300000                 0.85
# 9   vario-125   2018        16,800,000.00        16,733,625.20    9500000   22300000                 0.80
# 10  vario-125   2017        14,950,000.00        14,981,019.44   10500000   19800000                 0.72
# 11  vario-125   2016        13,950,000.00        14,048,137.25   10000000   20555000                 0.67
# 12     scoopy   2021        20,800,000.00        20,813,494.59    5500000   23500000                 1.00
# 13     scoopy   2020        20,000,000.00        19,215,769.23    4250000   23200000                 0.96
# 14     scoopy   2019        18,500,000.00        18,708,899.22   14500000   22700000                 0.89
# 15     scoopy   2018        17,725,000.00        17,447,291.54   12000000   21500000                 0.85
# 16     scoopy   2017        15,500,000.00        15,694,211.54   11500000   19800000                 0.75
# 17     scoopy   2016        13,800,000.00        13,806,012.36    9100000   20000000                 0.66
# 18        mio   2021        14,700,000.00        14,432,466.02   11300000   16700000                 1.00
# 19        mio   2020        12,500,000.00        12,969,230.77    8300000   16750000                 0.85
# 20        mio   2019        11,950,000.00        11,557,142.86    8500000   14950000                 0.81
# 21        mio   2018        10,300,000.00        10,070,754.72    6500000   13300000                 0.70
# 22        mio   2017         8,600,000.00         8,618,333.33    5900000   11000000                 0.59
# 23        mio   2016         7,800,550.00         8,245,642.00    4400000   12800000                 0.53
# 24       beat   2021        16,900,000.00        16,923,762.41   12000000   20500000                 1.00
# 25       beat   2020        15,950,000.00        15,862,937.50   12300000   20200000                 0.94
# 26       beat   2019        14,500,000.00        14,454,098.70    7800000   18750000                 0.86
# 27       beat   2018        13,900,000.00        13,759,590.74    7500000   18200000                 0.82
# 28       beat   2017        12,500,000.00        12,376,253.54    5000000   17000000                 0.74
# 29       beat   2016        11,425,000.00        11,309,713.04    7000000   17000000                 0.68

# %%
mb.set_index('years', inplace=True)
mb.groupby('type')['index'].plot(legend=True, figsize=(20,10))
mb = mb.reset_index()

# %%
mc.set_index('years', inplace=True)
mc.groupby('type')['index'].plot(legend=True, figsize=(20,10))
mc = mc.reset_index()

# %%
mb['pct_ch'] = mb.groupby('type')['price_mean'].pct_change()

# %%
print_full(mb)
# Out:
#     years       type         price_median           price_mean  price_min  price_max                index               pct_ch
# 0    2021  vario-150        22,575,000.00        22,200,411.52   17000000   24300000                 1.00                  NaN
# 1    2020  vario-150        20,000,000.00        20,250,264.33    8900000   24500000                 0.89                -0.09
# 2    2019  vario-150        19,700,000.00        19,587,955.41   14750000   24500000                 0.87                -0.03
# 3    2018  vario-150        18,500,000.00        18,365,690.07   12500000   23999000                 0.82                -0.06
# 4    2017  vario-150        16,450,000.00        16,141,633.32   12000000   20000000                 0.73                -0.12
# 5    2016  vario-150        15,225,000.00        15,523,195.48   12500000   19200000                 0.67                -0.04
# 6    2021  vario-125        20,900,000.00        20,606,493.98   16500000   23800000                 1.00                  NaN
# 7    2020  vario-125        19,000,000.00        19,045,653.52   15000000   22800000                 0.91                -0.08
# 8    2019  vario-125        17,850,000.00        17,665,330.71   11950000   24300000                 0.85                -0.07
# 9    2018  vario-125        16,800,000.00        16,733,625.20    9500000   22300000                 0.80                -0.05
# 10   2017  vario-125        14,950,000.00        14,981,019.44   10500000   19800000                 0.72                -0.10
# 11   2016  vario-125        13,950,000.00        14,048,137.25   10000000   20555000                 0.67                -0.06
# 12   2021     scoopy        20,800,000.00        20,813,494.59    5500000   23500000                 1.00                  NaN
# 13   2020     scoopy        20,000,000.00        19,215,769.23    4250000   23200000                 0.96                -0.08
# 14   2019     scoopy        18,500,000.00        18,708,899.22   14500000   22700000                 0.89                -0.03
# 15   2018     scoopy        17,725,000.00        17,447,291.54   12000000   21500000                 0.85                -0.07
# 16   2017     scoopy        15,500,000.00        15,694,211.54   11500000   19800000                 0.75                -0.10
# 17   2016     scoopy        13,800,000.00        13,806,012.36    9100000   20000000                 0.66                -0.12
# 18   2021        mio        14,700,000.00        14,432,466.02   11300000   16700000                 1.00                  NaN
# 19   2020        mio        12,500,000.00        12,969,230.77    8300000   16750000                 0.85                -0.10
# 20   2019        mio        11,950,000.00        11,557,142.86    8500000   14950000                 0.81                -0.11
# 21   2018        mio        10,300,000.00        10,070,754.72    6500000   13300000                 0.70                -0.13
# 22   2017        mio         8,600,000.00         8,618,333.33    5900000   11000000                 0.59                -0.14
# 23   2016        mio         7,800,550.00         8,245,642.00    4400000   12800000                 0.53                -0.04
# 24   2021       beat        16,900,000.00        16,923,762.41   12000000   20500000                 1.00                  NaN
# 25   2020       beat        15,950,000.00        15,862,937.50   12300000   20200000                 0.94                -0.06
# 26   2019       beat        14,500,000.00        14,454,098.70    7800000   18750000                 0.86                -0.09
# 27   2018       beat        13,900,000.00        13,759,590.74    7500000   18200000                 0.82                -0.05
# 28   2017       beat        12,500,000.00        12,376,253.54    5000000   17000000                 0.74                -0.10
# 29   2016       beat        11,425,000.00        11,309,713.04    7000000   17000000                 0.68                -0.09

# %%
mc['pct_ch'] = mc.groupby('type')['price_mean'].pct_change()

# %%
print_full(mc)
# Out:
#     years     type         price_median           price_mean  price_min  price_max                index               pct_ch
# 0    2021    yaris       264,000,000.00       257,086,956.52  229000000  285000000                 1.00                  NaN
# 1    2020    yaris       240,000,000.00       227,161,290.32  123000000  285000000                 0.91                -0.12
# 2    2019    yaris       235,000,000.00       235,895,156.55  205000000  265000000                 0.89                 0.04
# 3    2018    yaris       229,000,000.00       224,929,166.67  193000000  243000000                 0.87                -0.05
# 4    2017    yaris       178,800,000.00       182,323,017.84  141800000  210000000                 0.68                -0.19
# 5    2016    yaris       177,500,000.00       171,773,807.14  155000000  189000000                 0.67                -0.06
# 6    2021  xpander       273,500,000.00       269,291,304.35  234000000  296000000                 1.00                  NaN
# 7    2020  xpander       255,000,000.00       257,199,971.43  212000000  280000000                 0.93                -0.04
# 8    2019  xpander       229,000,000.00       227,784,451.01  185000000  266000000                 0.84                -0.11
# 9    2018  xpander       218,500,000.00       215,835,971.22  175000000  243000000                 0.80                -0.05
# 10   2017  xpander       200,000,000.00       202,412,500.00  182500000  225000000                 0.73                -0.06
# 11   2021     rush       255,000,000.00       256,214,228.57  243000000  280000000                 1.00                  NaN
# 12   2020     rush       239,300,000.00       240,654,999.97  225000000  269000000                 0.94                -0.06
# 13   2019     rush       231,500,000.00       230,489,062.48  207500000  258900000                 0.91                -0.04
# 14   2018     rush       222,999,000.00       220,362,159.42  150000000  250000000                 0.87                -0.04
# 15   2017     rush       180,000,000.00       178,262,500.00  165000000  198000000                 0.71                -0.19
# 16   2016     rush       175,000,000.00       172,700,000.00  152000000  185000000                 0.69                -0.03
# 17   2021     jazz       280,000,000.00       281,000,000.00  280000000  285000000                 1.00                  NaN
# 18   2020     jazz       272,000,000.00       271,533,266.67  215000000  332000000                 0.97                -0.03
# 19   2019     jazz       260,000,000.00       261,825,454.55  247500000  280000000                 0.93                -0.04
# 20   2018     jazz       245,000,000.00       241,726,874.99  189000000  285000000                 0.88                -0.08
# 21   2017     jazz       229,000,000.00       225,778,313.25  185000000  257000000                 0.82                -0.07
# 22   2016     jazz       206,500,000.00       206,796,969.67  179000000  235000000                 0.74                -0.08
# 23   2021   innova       385,000,000.00       387,340,425.51  287000000  460000000                 1.00                  NaN
# 24   2020   innova       383,000,000.00       367,664,705.88  280000000  463000000                 0.99                -0.05
# 25   2019   innova       338,000,000.00       339,851,898.73  245000000  430000000                 0.88                -0.08
# 26   2018   innova       316,000,000.00       315,194,444.44  199000000  409000000                 0.82                -0.07
# 27   2017   innova       318,250,000.00       312,005,555.56  245000000  395000000                 0.83                -0.01
# 28   2016   innova       278,000,000.00       286,738,095.24  242000000  340000000                 0.72                -0.08
# 29   2021     hr-v       325,000,000.00       327,611,111.11  295000000  389000000                 1.00                  NaN
# 30   2020     hr-v       307,500,000.00       317,641,500.00  279000000  365000000                 0.95                -0.03
# 31   2019     hr-v       288,800,000.00       292,165,242.13  250000000  354999999                 0.89                -0.08
# 32   2018     hr-v       285,000,000.00       279,846,938.78  214000000  351000000                 0.88                -0.04
# 33   2017     hr-v       238,000,000.00       245,456,138.60  199000000  315000000                 0.73                -0.12
# 34   2016     hr-v       219,000,000.00       220,428,052.61  177000000  283000000                 0.67                -0.10
# 35   2021     cr-v       552,000,000.00       549,000,000.00  515000000  570000000                 1.00                  NaN
# 36   2020     cr-v       499,000,000.00       504,800,000.00  489000000  529000000                 0.90                -0.08
# 37   2019     cr-v       457,700,000.00       449,007,333.26  399000000  495000000                 0.83                -0.11
# 38   2018     cr-v       440,000,000.00       433,633,333.33  340000000  480000000                 0.80                -0.03
# 39   2017     cr-v       340,000,000.00       352,025,581.40  275000000  465000000                 0.62                -0.19
# 40   2016     cr-v       274,500,000.00       276,349,999.95  225000000  315000000                 0.50                -0.21
# 41   2021     brio       176,000,000.00       178,269,354.82  150000000  211000000                 1.00                  NaN
# 42   2020     brio       168,500,000.00       170,287,234.04  142000000  200000000                 0.96                -0.04
# 43   2019     brio       167,000,000.00       167,381,944.44  138000000  199500000                 0.95                -0.02
# 44   2018     brio       140,000,000.00       142,624,691.36  114000000  183000000                 0.80                -0.15
# 45   2017     brio       132,250,000.00       132,128,301.89  112000000  152000000                 0.75                -0.07
# 46   2016     brio       130,000,000.00       127,779,636.36  105000000  155000000                 0.74                -0.03
# 47   2021   avanza       239,750,000.00       252,117,647.06  162000000  315000000                 1.00                  NaN
# 48   2020   avanza       196,000,000.00       200,000,000.00  165000000  275000000                 0.82                -0.21
# 49   2019   avanza       191,000,000.00       187,859,459.46  155000000  217000000                 0.80                -0.06
# 50   2018   avanza       164,000,000.00       161,627,450.98  135000000  191000000                 0.68                -0.14
# 51   2017   avanza       150,000,000.00       151,969,135.80  119000000  188000000                 0.63                -0.06
# 52   2016   avanza       147,500,000.00       145,806,153.85  120000000  170000000                 0.62                -0.04

# %%
mb.set_index('years', inplace=True)
mb.groupby('type')['pct_ch'].plot(legend=True, figsize=(20,10))
mb = mb.reset_index()

# %%
mc.set_index('years', inplace=True)
mc.groupby('type')['pct_ch'].plot(legend=True, figsize=(20,10))
mc = mc.reset_index()

# %%
mbx = mb.groupby(['years']).agg({'pct_ch': ['median','mean', 'min', 'max']}).sort_values(by=['years'], ascending=False)
mbx.columns = ['pct_median','pct_mean', 'pct_min', 'pct_max']
mbx = mbx.reset_index()
mbx = pd.DataFrame(data=mbx)

# %%
mbx = mbx.dropna()

# %%
mbx.set_index('years', inplace=True)
mbx['pct_mean'].plot(legend=True, figsize=(20,10))
mbx = mbx.reset_index()

# %%
mcx = mc.groupby(['years']).agg({'pct_ch': ['median','mean', 'min', 'max']}).sort_values(by=['years'], ascending=False)
mcx.columns = ['pct_median','pct_mean', 'pct_min', 'pct_max']
mcx = mcx.reset_index()
mcx = pd.DataFrame(data=mcx)

# %%
mcx = mcx.dropna()

# %%
mcx.set_index('years', inplace=True)
mcx['pct_mean'].plot(legend=True, figsize=(20,10))
mcx = mcx.reset_index()

# %%
mby = mb.groupby(['years']).agg({'index': ['median','mean', 'min', 'max']}).sort_values(by=['years'], ascending=False)
mby.columns = ['in_median','in_mean', 'in_min', 'in_max']
mby = mby.reset_index()
mby = pd.DataFrame(data=mby)

# %%
mby = mby.dropna()

# %%
mby.set_index('years', inplace=True)
mby['in_mean'].plot(legend=True, figsize=(20,10))
mby = mby.reset_index()

# %%
mcy =mc.groupby(['years']).agg({'index': ['median','mean', 'min', 'max']}).sort_values(by=['years'], ascending=False)
mcy.columns = ['in_median','in_mean', 'in_min', 'in_max']
mcy = mcy.reset_index()
mcy = pd.DataFrame(data=mcy)

# %%
mcy = mcy.dropna()

# %%
mcy.set_index('years', inplace=True)
mcy['in_mean'].plot(legend=True, figsize=(20,10))
mcy = mcy.reset_index()

# %%
dfb
# Out:
#                                                   title     price   brand  \
# 0     KREDIT YAMAHA MIO GEAR 2021 DP 3,000,000 PROSE...  15450000  yamaha
# 1     KREDIT DP 3,000,000 YAMAHA MIO GEAR 2021 ISTIMEWA  15450000  yamaha
# 2        (GRESS UNIT) DP 900 RB YAMAHA MIO GEAR TH 2021  14700000  yamaha
# 3                DP 900K YAMAHA MIO GEAR 125 CC TH 2021  14700000  yamaha
# 4                DP 900K YAMAHA MIO GEAR 125 CC TH 2021  14700000  yamaha
# ...                                                 ...       ...     ...
# 3447  beat esp 2016 bisa cash atau kredit ato tukart...   9000000   honda
# 3448  beat esp fi 2016 merah putih bisa cash atau kr...   9000000   honda
# 3449  beat esp 2016 bisa cash atau kredit ato tukart...   9000000   honda
# 3450  beat esp 2016 hitam bisa cash ato kredit ato t...   8800000   honda
# 3451  beat fi 2014 merah bisa cash ato kredit ato tu...   8300000   honda
#
#       type  years         milage                                    location  \
# 0      mio   2021  10.000-15.000   Pasar Rebo, Jakarta Timur, Jakarta D.K.I.
# 1      mio   2021  10.000-15.000     Cipayung, Jakarta Timur, Jakarta D.K.I.
# 2      mio   2021  10.000-15.000  Jagakarsa, Jakarta Selatan, Jakarta D.K.I.
# 3      mio   2021  10.000-15.000  Duren Sawit, Jakarta Timur, Jakarta D.K.I.
# 4      mio   2021  10.000-15.000           Cimanggis, Depok Kota, Jawa Barat
# ...    ...    ...            ...                                         ...
# 3447  beat   2016        0-5.000       Gamping, Sleman Kab., Yogyakarta D.I.
# 3448  beat   2016        0-5.000       Ngaglik, Sleman Kab., Yogyakarta D.I.
# 3449  beat   2016        0-5.000         Sewon, Bantul Kab., Yogyakarta D.I.
# 3450  beat   2016        0-5.000         Mlati, Sleman Kab., Yogyakarta D.I.
# 3451  beat   2016        0-5.000         Depok, Sleman Kab., Yogyakarta D.I.
#
#      vehicle_type                                                url  \
# 0            bike  https://www.olx.co.id/item/kredit-dp-3000000-y...
# 1            bike  https://www.olx.co.id/item/kredit-yamaha-mio-g...
# 2            bike  https://www.olx.co.id/item/dp-cuma-900-rb-aja-...
# 3            bike  https://www.olx.co.id/item/low-km-dp-900k-yama...
# 4            bike  https://www.olx.co.id/item/dp-cuma-900k-yamaha...
# ...           ...                                                ...
# 3447         bike  https://www.olx.co.id/item/beat-esp-2016-bisa-...
# 3448         bike  https://www.olx.co.id/item/beat-fi-esp-2016-bi...
# 3449         bike  https://www.olx.co.id/item/beat-esp-2016-bisa-...
# 3450         bike  https://www.olx.co.id/item/beat-esp-2016-merah...
# 3451         bike  https://www.olx.co.id/item/beat-fi-2016-bisa-k...
#
#       milage_class
# 0                3
# 1                3
# 2                3
# 3                3
# 4                3
# ...            ...
# 3447             1
# 3448             1
# 3449             1
# 3450             1
# 3451             1
#
# [3452 rows x 10 columns]

# %%
mb
# Out:
#     years       type  price_median    price_mean  price_min  price_max  \
# 0    2021  vario-150    22575000.0  2.220041e+07   17000000   24300000
# 1    2020  vario-150    20000000.0  2.025026e+07    8900000   24500000
# 2    2019  vario-150    19700000.0  1.958796e+07   14750000   24500000
# 3    2018  vario-150    18500000.0  1.836569e+07   12500000   23999000
# 4    2017  vario-150    16450000.0  1.614163e+07   12000000   20000000
# 5    2016  vario-150    15225000.0  1.552320e+07   12500000   19200000
# 6    2021  vario-125    20900000.0  2.060649e+07   16500000   23800000
# 7    2020  vario-125    19000000.0  1.904565e+07   15000000   22800000
# 8    2019  vario-125    17850000.0  1.766533e+07   11950000   24300000
# 9    2018  vario-125    16800000.0  1.673363e+07    9500000   22300000
# 10   2017  vario-125    14950000.0  1.498102e+07   10500000   19800000
# 11   2016  vario-125    13950000.0  1.404814e+07   10000000   20555000
# 12   2021     scoopy    20800000.0  2.081349e+07    5500000   23500000
# 13   2020     scoopy    20000000.0  1.921577e+07    4250000   23200000
# 14   2019     scoopy    18500000.0  1.870890e+07   14500000   22700000
# 15   2018     scoopy    17725000.0  1.744729e+07   12000000   21500000
# 16   2017     scoopy    15500000.0  1.569421e+07   11500000   19800000
# 17   2016     scoopy    13800000.0  1.380601e+07    9100000   20000000
# 18   2021        mio    14700000.0  1.443247e+07   11300000   16700000
# 19   2020        mio    12500000.0  1.296923e+07    8300000   16750000
# 20   2019        mio    11950000.0  1.155714e+07    8500000   14950000
# 21   2018        mio    10300000.0  1.007075e+07    6500000   13300000
# 22   2017        mio     8600000.0  8.618333e+06    5900000   11000000
# 23   2016        mio     7800550.0  8.245642e+06    4400000   12800000
# 24   2021       beat    16900000.0  1.692376e+07   12000000   20500000
# 25   2020       beat    15950000.0  1.586294e+07   12300000   20200000
# 26   2019       beat    14500000.0  1.445410e+07    7800000   18750000
# 27   2018       beat    13900000.0  1.375959e+07    7500000   18200000
# 28   2017       beat    12500000.0  1.237625e+07    5000000   17000000
# 29   2016       beat    11425000.0  1.130971e+07    7000000   17000000
#
#        index    pct_ch
# 0   1.000000       NaN
# 1   0.885936 -0.087843
# 2   0.872647 -0.032706
# 3   0.819491 -0.062399
# 4   0.728682 -0.121098
# 5   0.674419 -0.038313
# 6   1.000000       NaN
# 7   0.909091 -0.075745
# 8   0.854067 -0.072474
# 9   0.803828 -0.052742
# 10  0.715311 -0.104736
# 11  0.667464 -0.062271
# 12  1.000000       NaN
# 13  0.961538 -0.076764
# 14  0.889423 -0.026378
# 15  0.852163 -0.067434
# 16  0.745192 -0.100479
# 17  0.663462 -0.120312
# 18  1.000000       NaN
# 19  0.850340 -0.101385
# 20  0.812925 -0.108880
# 21  0.700680 -0.128612
# 22  0.585034 -0.144222
# 23  0.530650 -0.043244
# 24  1.000000       NaN
# 25  0.943787 -0.062683
# 26  0.857988 -0.088813
# 27  0.822485 -0.048049
# 28  0.739645 -0.100536
# 29  0.676036 -0.086176

# %%
mbx
# Out:
#    years  pct_median  pct_mean   pct_min   pct_max
# 0   2020   -0.076764 -0.080884 -0.101385 -0.062683
# 1   2019   -0.072474 -0.065850 -0.108880 -0.026378
# 2   2018   -0.062399 -0.071847 -0.128612 -0.048049
# 3   2017   -0.104736 -0.114214 -0.144222 -0.100479
# 4   2016   -0.062271 -0.070063 -0.120312 -0.038313

# %%
mby
# Out:
#    years  in_median   in_mean    in_min    in_max
# 0   2021   1.000000  1.000000  1.000000  1.000000
# 1   2020   0.909091  0.910138  0.850340  0.961538
# 2   2019   0.857988  0.857410  0.812925  0.889423
# 3   2018   0.819491  0.799729  0.700680  0.852163
# 4   2017   0.728682  0.702773  0.585034  0.745192
# 5   2016   0.667464  0.642406  0.530650  0.676036

# %%
dfc
# Out:
#              title      price   brand   type  years         milage  \
# 0     toyota yaris  264000000  toyota  yaris   2021  20.000-25.000
# 1     toyota yaris  264000000  toyota  yaris   2021  20.000-25.000
# 2     toyota yaris  264000000  toyota  yaris   2021  20.000-25.000
# 3     toyota yaris  264000000  toyota  yaris   2021  20.000-25.000
# 4     toyota yaris  264000000  toyota  yaris   2021  20.000-25.000
# ...            ...        ...     ...    ...    ...            ...
# 2853    honda brio  138000000   honda   brio   2016  45.000-50.000
# 2854    honda brio  137000000   honda   brio   2016  45.000-50.000
# 2855    honda brio  137000000   honda   brio   2016  45.000-50.000
# 2856    honda brio  137000000   honda   brio   2016  45.000-50.000
# 2857    honda brio  126000000   honda   brio   2016  45.000-50.000
#
#                                          location vehicle_type  \
# 0               Candi, Sidoarjo  Kab., Jawa Timur          car
# 1           Sambikerep, Surabaya Kota, Jawa Timur          car
# 2               Krian, Sidoarjo  Kab., Jawa Timur          car
# 3              Porong, Sidoarjo  Kab., Jawa Timur          car
# 4               Tarik, Sidoarjo  Kab., Jawa Timur          car
# ...                                           ...          ...
# 2853              Balung, Jember Kab., Jawa Timur          car
# 2854  Magelang Tengah, Magelang Kota, Jawa Tengah          car
# 2855   Kotagede, Yogyakarta Kota, Yogyakarta D.I.          car
# 2856      Prambanan, Sleman Kab., Yogyakarta D.I.          car
# 2857           Rungkut, Surabaya Kota, Jawa Timur          car
#
#                                                     url  milage_class    fuel  \
# 0     https://www.olx.co.id/item/olx-autos-toyota-ya...             5  Bensin
# 1     https://www.olx.co.id/item/olx-autos-toyota-ya...             5  Bensin
# 2     https://www.olx.co.id/item/olx-autos-toyota-ya...             5  Bensin
# 3     https://www.olx.co.id/item/olx-autos-toyota-ya...             5  Bensin
# 4     https://www.olx.co.id/item/olx-autos-toyota-ya...             5  Bensin
# ...                                                 ...           ...     ...
# 2853  https://www.olx.co.id/item/honda-brio-rs-mt-ii...            10  Bensin
# 2854  https://www.olx.co.id/item/dp-21jt-honda-brio-...            10  Bensin
# 2855  https://www.olx.co.id/item/dp-24-jt-honda-brio...            10  Bensin
# 2856  https://www.olx.co.id/item/dp-17juta-brio-rs-a...            10  Bensin
# 2857  https://www.olx.co.id/item/honda-brio-e-satya-...            10  Bensin
#
#      transmission
# 0       Automatic
# 1       Automatic
# 2       Automatic
# 3       Automatic
# 4       Automatic
# ...           ...
# 2853       Manual
# 2854    Automatic
# 2855    Automatic
# 2856    Automatic
# 2857       Manual
#
# [2858 rows x 12 columns]

# %%
mc
# Out:
#     years     type  price_median    price_mean  price_min  price_max  \
# 0    2021    yaris   264000000.0  2.570870e+08  229000000  285000000
# 1    2020    yaris   240000000.0  2.271613e+08  123000000  285000000
# 2    2019    yaris   235000000.0  2.358952e+08  205000000  265000000
# 3    2018    yaris   229000000.0  2.249292e+08  193000000  243000000
# 4    2017    yaris   178800000.0  1.823230e+08  141800000  210000000
# 5    2016    yaris   177500000.0  1.717738e+08  155000000  189000000
# 6    2021  xpander   273500000.0  2.692913e+08  234000000  296000000
# 7    2020  xpander   255000000.0  2.572000e+08  212000000  280000000
# 8    2019  xpander   229000000.0  2.277845e+08  185000000  266000000
# 9    2018  xpander   218500000.0  2.158360e+08  175000000  243000000
# 10   2017  xpander   200000000.0  2.024125e+08  182500000  225000000
# 11   2021     rush   255000000.0  2.562142e+08  243000000  280000000
# 12   2020     rush   239300000.0  2.406550e+08  225000000  269000000
# 13   2019     rush   231500000.0  2.304891e+08  207500000  258900000
# 14   2018     rush   222999000.0  2.203622e+08  150000000  250000000
# 15   2017     rush   180000000.0  1.782625e+08  165000000  198000000
# 16   2016     rush   175000000.0  1.727000e+08  152000000  185000000
# 17   2021     jazz   280000000.0  2.810000e+08  280000000  285000000
# 18   2020     jazz   272000000.0  2.715333e+08  215000000  332000000
# 19   2019     jazz   260000000.0  2.618255e+08  247500000  280000000
# 20   2018     jazz   245000000.0  2.417269e+08  189000000  285000000
# 21   2017     jazz   229000000.0  2.257783e+08  185000000  257000000
# 22   2016     jazz   206500000.0  2.067970e+08  179000000  235000000
# 23   2021   innova   385000000.0  3.873404e+08  287000000  460000000
# 24   2020   innova   383000000.0  3.676647e+08  280000000  463000000
# 25   2019   innova   338000000.0  3.398519e+08  245000000  430000000
# 26   2018   innova   316000000.0  3.151944e+08  199000000  409000000
# 27   2017   innova   318250000.0  3.120056e+08  245000000  395000000
# 28   2016   innova   278000000.0  2.867381e+08  242000000  340000000
# 29   2021     hr-v   325000000.0  3.276111e+08  295000000  389000000
# 30   2020     hr-v   307500000.0  3.176415e+08  279000000  365000000
# 31   2019     hr-v   288800000.0  2.921652e+08  250000000  354999999
# 32   2018     hr-v   285000000.0  2.798469e+08  214000000  351000000
# 33   2017     hr-v   238000000.0  2.454561e+08  199000000  315000000
# 34   2016     hr-v   219000000.0  2.204281e+08  177000000  283000000
# 35   2021     cr-v   552000000.0  5.490000e+08  515000000  570000000
# 36   2020     cr-v   499000000.0  5.048000e+08  489000000  529000000
# 37   2019     cr-v   457700000.0  4.490073e+08  399000000  495000000
# 38   2018     cr-v   440000000.0  4.336333e+08  340000000  480000000
# 39   2017     cr-v   340000000.0  3.520256e+08  275000000  465000000
# 40   2016     cr-v   274500000.0  2.763500e+08  225000000  315000000
# 41   2021     brio   176000000.0  1.782694e+08  150000000  211000000
# 42   2020     brio   168500000.0  1.702872e+08  142000000  200000000
# 43   2019     brio   167000000.0  1.673819e+08  138000000  199500000
# 44   2018     brio   140000000.0  1.426247e+08  114000000  183000000
# 45   2017     brio   132250000.0  1.321283e+08  112000000  152000000
# 46   2016     brio   130000000.0  1.277796e+08  105000000  155000000
# 47   2021   avanza   239750000.0  2.521176e+08  162000000  315000000
# 48   2020   avanza   196000000.0  2.000000e+08  165000000  275000000
# 49   2019   avanza   191000000.0  1.878595e+08  155000000  217000000
# 50   2018   avanza   164000000.0  1.616275e+08  135000000  191000000
# 51   2017   avanza   150000000.0  1.519691e+08  119000000  188000000
# 52   2016   avanza   147500000.0  1.458062e+08  120000000  170000000
#
#        index    pct_ch
# 0   1.000000       NaN
# 1   0.909091 -0.116403
# 2   0.890152  0.038448
# 3   0.867424 -0.046487
# 4   0.677273 -0.189420
# 5   0.672348 -0.057860
# 6   1.000000       NaN
# 7   0.932358 -0.044901
# 8   0.837294 -0.114368
# 9   0.798903 -0.052455
# 10  0.731261 -0.062193
# 11  1.000000       NaN
# 12  0.938431 -0.060727
# 13  0.907843 -0.042243
# 14  0.874506 -0.043937
# 15  0.705882 -0.191048
# 16  0.686275 -0.031204
# 17  1.000000       NaN
# 18  0.971429 -0.033689
# 19  0.928571 -0.035752
# 20  0.875000 -0.076763
# 21  0.817857 -0.065978
# 22  0.737500 -0.084071
# 23  1.000000       NaN
# 24  0.994805 -0.050797
# 25  0.877922 -0.075647
# 26  0.820779 -0.072554
# 27  0.826623 -0.010117
# 28  0.722078 -0.080984
# 29  1.000000       NaN
# 30  0.946154 -0.030431
# 31  0.888615 -0.080204
# 32  0.876923 -0.042162
# 33  0.732308 -0.122891
# 34  0.673846 -0.101966
# 35  1.000000       NaN
# 36  0.903986 -0.080510
# 37  0.829167 -0.110524
# 38  0.797101 -0.034240
# 39  0.615942 -0.188195
# 40  0.497283 -0.214972
# 41  1.000000       NaN
# 42  0.957386 -0.044776
# 43  0.948864 -0.017061
# 44  0.795455 -0.147909
# 45  0.751420 -0.073594
# 46  0.738636 -0.032912
# 47  1.000000       NaN
# 48  0.817518 -0.206720
# 49  0.796663 -0.060703
# 50  0.684046 -0.139636
# 51  0.625652 -0.059757
# 52  0.615224 -0.040554

# %%
mcx
# Out:
#    years  pct_median  pct_mean   pct_min   pct_max
# 0   2020   -0.050797 -0.074328 -0.206720 -0.030431
# 1   2019   -0.060703 -0.055339 -0.114368  0.038448
# 2   2018   -0.052455 -0.072905 -0.147909 -0.034240
# 3   2017   -0.073594 -0.107022 -0.191048 -0.010117
# 4   2016   -0.069422 -0.080565 -0.214972 -0.031204

# %%
mcy
# Out:
#    years  in_median   in_mean    in_min    in_max
# 0   2021   1.000000  1.000000  1.000000  1.000000
# 1   2020   0.938431  0.930129  0.817518  0.994805
# 2   2019   0.888615  0.878343  0.796663  0.948864
# 3   2018   0.820779  0.821126  0.684046  0.876923
# 4   2017   0.731261  0.720469  0.615942  0.826623
# 5   2016   0.680060  0.667899  0.497283  0.738636

# %%
dfb.to_csv('Output\Final_Bike_To-Viz.csv', index=False)
mb.to_csv('Output\Final_Bike_To-Viz_Agg-Bike-Type.csv', index=False)
mbx.to_csv('Output\Final_Bike_To-Viz_Yearly-Pct.csv', index=False)
mby.to_csv('Output\Final_Bike_To-Viz_Yearly-Index.csv', index=False)

# %%
dfc.to_csv('Output\Final_Car_To-Viz.csv', index=False)
mc.to_csv('Output\Final_Car_To-Viz_Agg-Car-Type.csv', index=False)
mcx.to_csv('Output\Final_Car_To-Viz_Yearly-Pct.csv', index=False)
mcy.to_csv('Output\Final_Car_To-Viz_Yearly-Index.csv', index=False)
